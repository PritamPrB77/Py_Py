# %%
import numpy as np
from scipy import stats

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\pritam\appdata\local\programs\python\python313\lib\site-packages (1.16.1)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\pritam\appdata\local\programs\python\python313\lib\site-packages (from scipy) (2.2.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = [10, 20, 30, 40, 50, 60, 60, 60, 60, 70, 80, 90, 90, 90, 90, 100]

# %%
print(np.mean(data))
# Out:
# 62.5

# %%
print(np.median(data))
# Out:
# 60.0

# %%
mode_via_scipy = stats.mode(data)

# %%
print(stats.mode(data))
# Out:
# ModeResult(mode=np.int64(60), count=np.int64(4))

# %%
mode_via_scipy[0]
# Out:
# np.int64(60)

# %%
mode_via_scipy[1]
# Out:
# np.int64(4)

# %%
scores = [60, 70, 75, 80, 85, 90, 95]

# %%
q1 = np.percentile(scores, 25) # Q1
print(q1)
q3 = np.percentile(scores, 75) # Q1
print(q3)
# Out:
# 72.5
# 87.5

# %%
(70+ 75)/2
# Out:
# 72.5

# %%
IQR = q3-q1 # tells us how spread data is in the middle 50% of the data

# %%
print(IQR)
# Out:
# 15.0
